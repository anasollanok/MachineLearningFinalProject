# %%
# Final Project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import csv
import random
# %matplotlib inline
from numpy import genfromtxt
from keras import Sequential
from keras import callbacks
from keras.layers import Dense
from keras.initializers import glorot_normal
from keras.optimizers import SGD

# For tensorboard
tbCallBack = callbacks.TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)

# %%
# Loading data from the csv
airQuality = pd.read_csv("indice_2017Rev.csv")
airQuality
# Out:
#             Fecha  Hora  Ozono  Dioxido de azufre  Dioxido de nitrogeno  \
# 0          1/1/17     1    9.0               18.0                  18.0
# 1          1/1/17     2    5.0               15.0                  17.0
# 2          1/1/17     3    6.0               12.0                  16.0
# 3          1/1/17     4    3.0                9.0                  17.0
# 4          1/1/17     5    3.0                8.0                  16.0
# 5          1/1/17     6    4.0                6.0                  15.0
# 6          1/1/17     7    4.0                6.0                  15.0
# 7          1/1/17     8    4.0                5.0                  13.0
# 8          1/1/17     9   11.0                5.0                  16.0
# 9          1/1/17    10   23.0                5.0                  23.0
# 10         1/1/17    11   39.0                4.0                  18.0
# 11         1/1/17    12   48.0                4.0                  10.0
# 12         1/1/17    13   61.0                4.0                   8.0
# 13         1/1/17    14   90.0                4.0                   6.0
# 14         1/1/17    15   92.0                3.0                   6.0
# 15         1/1/17    16  100.0                3.0                   7.0
# 16         1/1/17    17   88.0                3.0                   9.0
# 17         1/1/17    18   67.0                3.0                  11.0
# 18         1/1/17    19   42.0                3.0                  10.0
# 19         1/1/17    20   26.0                3.0                  17.0
# 20         1/1/17    21   22.0                3.0                  19.0
# 21         1/1/17    22   23.0                3.0                  22.0
# 22         1/1/17    23   18.0                3.0                  26.0
# 23         1/1/17    24    6.0                3.0                  25.0
# 24         2/1/17     1    8.0                3.0                  20.0
# 25         2/1/17     2    8.0                3.0                  19.0
# 26         2/1/17     3    6.0                3.0                  17.0
# 27         2/1/17     4    9.0                3.0                  19.0
# 28         2/1/17     5    9.0                3.0                  17.0
# 29         2/1/17     6    4.0                3.0                  16.0
# ...           ...   ...    ...                ...                   ...
# 43770  30/12/2017    19   44.0               11.0                  13.0
# 43771  30/12/2017    20   26.0               11.0                  20.0
# 43772  30/12/2017    21   17.0               12.0                  24.0
# 43773  30/12/2017    22   16.0               12.0                  30.0
# 43774  30/12/2017    23    7.0               12.0                  29.0
# 43775  30/12/2017    24    NaN               12.0                   NaN
# 43776  31/12/2017     1    NaN               12.0                   NaN
# 43777  31/12/2017     2    NaN               12.0                   NaN
# 43778  31/12/2017     3    NaN               12.0                   NaN
# 43779  31/12/2017     4    5.0               12.0                  18.0
# 43780  31/12/2017     5    5.0                9.0                  19.0
# 43781  31/12/2017     6    4.0                8.0                  20.0
# 43782  31/12/2017     7    5.0                6.0                  20.0
# 43783  31/12/2017     8    3.0                5.0                  19.0
# 43784  31/12/2017     9    6.0                5.0                  20.0
# 43785  31/12/2017    10   18.0                5.0                  20.0
# 43786  31/12/2017    11   34.0                5.0                  16.0
# 43787  31/12/2017    12   48.0                5.0                  14.0
# 43788  31/12/2017    13   69.0                5.0                   5.0
# 43789  31/12/2017    14   76.0                5.0                   5.0
# 43790  31/12/2017    15   90.0                5.0                   6.0
# 43791  31/12/2017    16  103.0                5.0                   6.0
# 43792  31/12/2017    17  103.0                5.0                   8.0
# 43793  31/12/2017    18  101.0                5.0                  10.0
# 43794  31/12/2017    19   48.0                5.0                  12.0
# 43795  31/12/2017    20   39.0                5.0                  12.0
# 43796  31/12/2017    21   33.0                4.0                  23.0
# 43797  31/12/2017    22   21.0                4.0                  24.0
# 43798  31/12/2017    23   12.0                4.0                  24.0
# 43799  31/12/2017    24   11.0                4.0                  26.0
#
#        Monoxido de carbono   pm10  Zona
# 0                     12.0   80.0     1
# 1                     13.0   86.0     1
# 2                     13.0   94.0     1
# 3                     13.0  100.0     1
# 4                     13.0  103.0     1
# 5                     13.0  106.0     1
# 6                     12.0  108.0     1
# 7                     12.0  110.0     1
# 8                     11.0  111.0     1
# 9                     11.0  113.0     1
# 10                    11.0  114.0     1
# 11                    10.0  115.0     1
# 12                     9.0  115.0     1
# 13                     7.0  113.0     1
# 14                     7.0  112.0     1
# 15                     6.0  112.0     1
# 16                     5.0  112.0     1
# 17                     5.0  112.0     1
# 18                     5.0  112.0     1
# 19                     5.0  113.0     1
# 20                     5.0  112.0     1
# 21                     6.0  112.0     1
# 22                     6.0  112.0     1
# 23                     7.0  112.0     1
# 24                     7.0  111.0     1
# 25                     8.0  110.0     1
# 26                     8.0  108.0     1
# 27                     7.0  106.0     1
# 28                     7.0  105.0     1
# 29                     7.0  102.0     1
# ...                    ...    ...   ...
# 43770                  5.0   68.0     5
# 43771                  5.0   67.0     5
# 43772                  5.0   70.0     5
# 43773                  5.0   71.0     5
# 43774                  5.0   71.0     5
# 43775                  7.0   74.0     5
# 43776                  7.0   74.0     5
# 43777                  8.0   74.0     5
# 43778                  NaN   76.0     5
# 43779                  NaN   76.0     5
# 43780                  NaN   77.0     5
# 43781                  NaN   78.0     5
# 43782                  NaN   80.0     5
# 43783                  NaN   81.0     5
# 43784                  9.0   84.0     5
# 43785                  9.0   84.0     5
# 43786                  9.0   81.0     5
# 43787                  9.0   78.0     5
# 43788                  8.0   76.0     5
# 43789                  7.0   76.0     5
# 43790                  7.0   77.0     5
# 43791                  6.0   78.0     5
# 43792                  5.0   77.0     5
# 43793                  5.0   80.0     5
# 43794                  5.0   77.0     5
# 43795                  5.0   78.0     5
# 43796                  6.0   77.0     5
# 43797                  6.0   80.0     5
# 43798                  7.0   83.0     5
# 43799                  9.0   87.0     5
#
# [43800 rows x 8 columns]

# %%
# Get the info from the dataset
airQuality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43800 entries, 0 to 43799
# Data columns (total 8 columns):
# Fecha                   43800 non-null object
# Hora                    43800 non-null int64
# Ozono                   42756 non-null float64
# Dioxido de azufre       43782 non-null float64
# Dioxido de nitrogeno    42741 non-null float64
# Monoxido de carbono     41969 non-null float64
# pm10                    42802 non-null float64
# Zona                    43800 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 2.7+ MB

# %%
# Feature Engineering
# Checking impact of hour
airQuality[['Hora', 'Ozono']].groupby(['Hora'], as_index=False).mean()
# Out:
#     Hora      Ozono
# 0      1  16.321981
# 1      2  15.601974
# 2      3  15.033553
# 3      4  14.156495
# 4      5  12.858630
# 5      6  10.131507
# 6      7   7.658082
# 7      8   6.627945
# 8      9   9.212055
# 9     10  15.927671
# 10    11  25.070137
# 11    12  36.505205
# 12    13  51.462466
# 13    14  66.560307
# 14    15  76.296986
# 15    16  75.930411
# 16    17  67.737534
# 17    18  53.450959
# 18    19  38.406027
# 19    20  29.808767
# 20    21  23.874521
# 21    22  20.353425
# 22    23  18.143562
# 23    24  16.877540

# %%
# Filling empty Sulfur Dioxide rows with the median
so2Median = airQuality['Dioxido de azufre'].median()
airQuality['Dioxido de azufre'] = airQuality['Dioxido de azufre'].fillna(so2Median)
# Grouping in 4
airQuality['CategoricalSO2'] = pd.qcut(airQuality['Dioxido de azufre'], 4)
# Checking impact
airQuality[['CategoricalSO2', 'Ozono']].groupby(['CategoricalSO2'], as_index=False).mean()
# We can see that it does not have an impact as it Sulfur Dioxide is fairly uniform with respect of Ozone.
# Therefore, we may drop this feature.
# Out:
#   CategoricalSO2      Ozono
# 0   (0.999, 2.0]  29.732082
# 1     (2.0, 3.0]  32.455719
# 2     (3.0, 6.0]  32.271811
# 3    (6.0, 69.0]  29.208723

# %%
# Filling empty Nitrogen Dioxide rows with the median
no2Median = airQuality['Dioxido de nitrogeno'].median()
airQuality['Dioxido de nitrogeno'] = airQuality['Dioxido de nitrogeno'].fillna(no2Median)
# Grouping in 4
airQuality['CategoricalNO2'] = pd.qcut(airQuality['Dioxido de nitrogeno'], 4)
# Checking impact
airQuality[['CategoricalNO2', 'Ozono']].groupby(['CategoricalNO2'], as_index=False).mean()
# This feature does have some impact, we are going to keep this one.
# Out:
#    CategoricalNO2      Ozono
# 0  (-0.001, 10.0]  42.081998
# 1    (10.0, 15.0]  30.437596
# 2    (15.0, 20.0]  24.425985
# 3    (20.0, 62.0]  22.531719

# %%
# Filling empty Carbon Monoxide rows with the median
coMedian = airQuality['Monoxido de carbono'].median()
airQuality['Monoxido de carbono'] = airQuality['Monoxido de carbono'].fillna(coMedian)
# Grouping in 3
airQuality['CategoricalCO'] = pd.qcut(airQuality['Monoxido de carbono'], 4)
# Checking impact
airQuality[['CategoricalCO', 'Ozono']].groupby(['CategoricalCO'], as_index=False).mean()
# This feature has little changing impact, but may be important to keep it.
# Out:
#   CategoricalCO      Ozono
# 0  (0.999, 5.0]  25.139447
# 1    (5.0, 6.0]  26.846353
# 2    (6.0, 8.0]  35.235867
# 3   (8.0, 35.0]  38.132183

# %%
# Filling empty Nitrogen Dioxide rows with the median
pmMedian = airQuality['pm10'].median()
airQuality['pm10'] = airQuality['pm10'].fillna(pmMedian)
# Grouping in 3
airQuality['CategoricalPM'] = pd.qcut(airQuality['pm10'], 4)
# Checking impact
airQuality[['CategoricalPM', 'Ozono']].groupby(['CategoricalPM'], as_index=False).mean()
# It does have an impact on Ozone, we will keep it.
# Out:
#    CategoricalPM      Ozono
# 0  (7.999, 44.0]  23.993164
# 1   (44.0, 64.0]  31.909133
# 2   (64.0, 94.0]  33.968850
# 3  (94.0, 162.0]  32.640509

# %%
# Checking impact of Zone
airQuality[['Zona', 'Ozono']].groupby(['Zona'], as_index=False).mean()
# Out:
#    Zona      Ozono
# 0     1  27.599275
# 1     2  28.647059
# 2     3  28.330097
# 3     4  36.234304
# 4     5  31.818384

# %%
# Working dates: 24 measures by day
dayOfYear = np.full((43800, 1), 0)
number = 1
index = 0
for day in range(0,1825):
    for measure in range (0, 24):
        np.put(dayOfYear, index, number)
        index = index + 1
    number = number + 1
    if number == 366:
        number = 1
airQuality['DaysOfYear'] = dayOfYear
# Grouping by month (approx)
airQuality['CategoricalDays'] = pd.qcut(airQuality['DaysOfYear'], 12)
# Checking impact
airQuality[['CategoricalDays', 'Ozono']].groupby(['CategoricalDays'], as_index=False).mean()
# Out:
#    CategoricalDays      Ozono
# 0    (0.999, 31.0]  30.065021
# 1     (31.0, 61.0]  34.631669
# 2     (61.0, 92.0]  30.992306
# 3    (92.0, 122.0]  40.267236
# 4   (122.0, 153.0]  46.997257
# 5   (153.0, 183.0]  33.610556
# 6   (183.0, 213.0]  25.279943
# 7   (213.0, 244.0]  24.925377
# 8   (244.0, 274.0]  21.924765
# 9   (274.0, 305.0]  26.112742
# 10  (305.0, 335.0]  23.787948
# 11  (335.0, 365.0]  27.457550

# %%
# Filling Ozone's missing values
o3Median = airQuality['Ozono'].median()
airQuality['Ozono'] = airQuality['Ozono'].fillna(pmMedian)
# all filled and grouped!

# %%
# Mapping nitrogen dioxide
airQuality.loc[airQuality['Dioxido de nitrogeno'] <= 10.0, 'Dioxido de nitrogeno'] = 0
airQuality.loc[(airQuality['Dioxido de nitrogeno'] > 10.0) & (airQuality['Dioxido de nitrogeno'] <= 15.0), 'Dioxido de nitrogeno'] = 1
airQuality.loc[(airQuality['Dioxido de nitrogeno'] > 15.0) & (airQuality['Dioxido de nitrogeno'] <= 20.0), 'Dioxido de nitrogeno'] = 2
airQuality.loc[airQuality['Dioxido de nitrogeno'] > 20, 'Dioxido de nitrogeno'] = 3
airQuality['Dioxido de nitrogeno'] = airQuality['Dioxido de nitrogeno'].astype(int)

# %%
# Mapping Carbon Monoxide
airQuality.loc[airQuality['Monoxido de carbono'] <= 5, 'Monoxido de carbono'] = 0
airQuality.loc[(airQuality['Monoxido de carbono'] > 5) & (airQuality['Monoxido de carbono'] <= 6), 'Monoxido de carbono'] = 1
airQuality.loc[(airQuality['Monoxido de carbono'] > 6) & (airQuality['Monoxido de carbono'] <= 8), 'Monoxido de carbono'] = 2
airQuality.loc[airQuality['Monoxido de carbono'] > 8, 'Monoxido de carbono'] = 3
airQuality['Monoxido de carbono'] = airQuality['Monoxido de carbono'].astype(int)

# %%
# Mapping PM10
airQuality.loc[airQuality['pm10'] <= 44, 'pm10'] = 0
airQuality.loc[(airQuality['pm10'] > 44) & (airQuality['pm10'] <= 64), 'pm10'] = 1
airQuality.loc[(airQuality['pm10'] > 64) & (airQuality['pm10'] <= 94), 'pm10'] = 2
airQuality.loc[airQuality['pm10'] > 94, 'pm10'] = 3
airQuality['pm10'] = airQuality['pm10'].astype(int)

# %%
# Mapping days
airQuality.loc[airQuality['DaysOfYear'] <= 31, 'DaysOfYear'] = 0
airQuality.loc[(airQuality['DaysOfYear'] > 31) & (airQuality['DaysOfYear'] <= 61), 'DaysOfYear'] = 1
airQuality.loc[(airQuality['DaysOfYear'] > 61) & (airQuality['DaysOfYear'] <= 92), 'DaysOfYear'] = 2
airQuality.loc[(airQuality['DaysOfYear'] > 92) & (airQuality['DaysOfYear'] <= 122), 'DaysOfYear'] = 3
airQuality.loc[(airQuality['DaysOfYear'] > 122) & (airQuality['DaysOfYear'] <= 153), 'DaysOfYear'] = 4
airQuality.loc[(airQuality['DaysOfYear'] > 153) & (airQuality['DaysOfYear'] <= 183), 'DaysOfYear'] = 5
airQuality.loc[(airQuality['DaysOfYear'] > 183) & (airQuality['DaysOfYear'] <= 213), 'DaysOfYear'] = 6
airQuality.loc[(airQuality['DaysOfYear'] > 213) & (airQuality['DaysOfYear'] <= 244), 'DaysOfYear'] = 7
airQuality.loc[(airQuality['DaysOfYear'] > 244) & (airQuality['DaysOfYear'] <= 274), 'DaysOfYear'] = 8
airQuality.loc[(airQuality['DaysOfYear'] > 274) & (airQuality['DaysOfYear'] <= 305), 'DaysOfYear'] = 9
airQuality.loc[(airQuality['DaysOfYear'] > 305) & (airQuality['DaysOfYear'] <= 335), 'DaysOfYear'] = 10
airQuality.loc[airQuality['DaysOfYear'] > 335, 'DaysOfYear'] = 11
airQuality['DaysOfYear'] = airQuality['DaysOfYear'].astype(int)

# %%
dropFeat = ['Fecha', 'Dioxido de azufre', 'CategoricalSO2', 'CategoricalNO2', 'CategoricalCO', 'CategoricalPM', 'CategoricalDays']
airQuality = airQuality.drop(dropFeat, axis=1)

results = np.array(airQuality)

X = results[:, [0, 2, 3, 4, 5, 6]]
Y = results[:, [1]]

# Normalization
X = X / np.linalg.norm(X)
Y = Y / np.linalg.norm(Y)
# Splitting data into train and test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=73)

# %%
out_dimension = 1
nHidden = 4
nInputDimension = X_train.shape[1]

# Building the model and then running it
model = Sequential()
model.add(Dense(nHidden, input_dim = nInputDimension, activation = 'relu', kernel_initializer = glorot_normal(seed=0)))
model.add(Dense(out_dimension, activation = 'sigmoid', kernel_initializer = glorot_normal(seed=0)))

sgd = SGD(lr=0.05, decay=1e-6, momentum=0.5, nesterov=True) # optimizer

model.compile(loss='mean_squared_logarithmic_error', optimizer=sgd, metrics=['mae'])

# Last parameter (callbacks) is important for TensorBoard
train = model.fit(X_train, Y_train, epochs=100, callbacks=[tbCallBack])

# Evaluating model
score = model.evaluate(X_test, Y_test, batch_size=25)
score
# Out:
# Epoch 1/100
# 32850/32850 [==============================] - 1s 41us/step - loss: 0.0152 - mean_absolute_error: 0.1022
# Epoch 2/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 6.2050e-04 - mean_absolute_error: 0.0248
# Epoch 3/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 2.6685e-04 - mean_absolute_error: 0.0161
# Epoch 4/100
# 32850/32850 [==============================] - 1s 32us/step - loss: 1.5945e-04 - mean_absolute_error: 0.0123
# Epoch 5/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 1.1012e-04 - mean_absolute_error: 0.0101
# Epoch 6/100
# 32850/32850 [==============================] - 2s 67us/step - loss: 8.2642e-05 - mean_absolute_error: 0.0087
# Epoch 7/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 6.5504e-05 - mean_absolute_error: 0.0077
# Epoch 8/100
# 32850/32850 [==============================] - 2s 46us/step - loss: 5.3976e-05 - mean_absolute_error: 0.0069
# Epoch 9/100
# 32850/32850 [==============================] - 2s 48us/step - loss: 4.5795e-05 - mean_absolute_error: 0.0064
# Epoch 10/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 3.9748e-05 - mean_absolute_error: 0.0059
# Epoch 11/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 3.5135e-05 - mean_absolute_error: 0.0056
# Epoch 12/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 3.1527e-05 - mean_absolute_error: 0.0052
# Epoch 13/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 2.8646e-05 - mean_absolute_error: 0.0050: 0s - loss: 2.9700e-05 - mean_absolute
# Epoch 14/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 2.6305e-05 - mean_absolute_error: 0.0048
# Epoch 15/100
# 32850/32850 [==============================] - 1s 42us/step - loss: 2.4376e-05 - mean_absolute_error: 0.0046
# Epoch 16/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 2.2766e-05 - mean_absolute_error: 0.0044
# Epoch 17/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 2.1407e-05 - mean_absolute_error: 0.0043
# Epoch 18/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 2.0249e-05 - mean_absolute_error: 0.0041
# Epoch 19/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.9255e-05 - mean_absolute_error: 0.0040
# Epoch 20/100
# 32850/32850 [==============================] - 1s 45us/step - loss: 1.8394e-05 - mean_absolute_error: 0.0039
# Epoch 21/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.7645e-05 - mean_absolute_error: 0.0038
# Epoch 22/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.6987e-05 - mean_absolute_error: 0.0038
# Epoch 23/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.6408e-05 - mean_absolute_error: 0.0037: 0s - loss: 1.6546e-05 - mean_abso
# Epoch 24/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.5895e-05 - mean_absolute_error: 0.0036
# Epoch 25/100
# 32850/32850 [==============================] - 1s 37us/step - loss: 1.5438e-05 - mean_absolute_error: 0.0035
# Epoch 26/100
# 32850/32850 [==============================] - 1s 37us/step - loss: 1.5031e-05 - mean_absolute_error: 0.0035
# Epoch 27/100
# 32850/32850 [==============================] - 1s 40us/step - loss: 1.4665e-05 - mean_absolute_error: 0.0034
# Epoch 28/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.4336e-05 - mean_absolute_error: 0.0034
# Epoch 29/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 1.4039e-05 - mean_absolute_error: 0.0033
# Epoch 30/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.3770e-05 - mean_absolute_error: 0.0033
# Epoch 31/100
# 32850/32850 [==============================] - 1s 40us/step - loss: 1.3525e-05 - mean_absolute_error: 0.0032
# Epoch 32/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.3303e-05 - mean_absolute_error: 0.0032: 0s - loss: 1.3295e-05 - mean_absolute_error: 0.003
# Epoch 33/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.3100e-05 - mean_absolute_error: 0.0032
# Epoch 34/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.2914e-05 - mean_absolute_error: 0.0031: 0s - loss: 1.3096e-05 - mean_absolute_e
# Epoch 35/100
# 32850/32850 [==============================] - 1s 43us/step - loss: 1.2744e-05 - mean_absolute_error: 0.0031
# Epoch 36/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.2588e-05 - mean_absolute_error: 0.0031
# Epoch 37/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.2444e-05 - mean_absolute_error: 0.0031
# Epoch 38/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.2311e-05 - mean_absolute_error: 0.0030
# Epoch 39/100
# 32850/32850 [==============================] - 1s 42us/step - loss: 1.2188e-05 - mean_absolute_error: 0.0030: 0s - loss: 1.2145e-05 - mean_absolute_error:
# Epoch 40/100
# 32850/32850 [==============================] - 1s 42us/step - loss: 1.2075e-05 - mean_absolute_error: 0.0030
# Epoch 41/100
# 32850/32850 [==============================] - 1s 45us/step - loss: 1.1970e-05 - mean_absolute_error: 0.0030: 0s - loss: 1.1981e-05 - mean_absolute_error: 0.0
# Epoch 42/100
# 32850/32850 [==============================] - 2s 52us/step - loss: 1.1872e-05 - mean_absolute_error: 0.0029
# Epoch 43/100
# 32850/32850 [==============================] - 2s 57us/step - loss: 1.1782e-05 - mean_absolute_error: 0.0029
# Epoch 44/100
# 32850/32850 [==============================] - 2s 55us/step - loss: 1.1698e-05 - mean_absolute_error: 0.0029
# Epoch 45/100
# 32850/32850 [==============================] - 1s 44us/step - loss: 1.1619e-05 - mean_absolute_error: 0.0029: 1s - loss: 1.1637e-05 - mea
# Epoch 46/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.1546e-05 - mean_absolute_error: 0.0029
# Epoch 47/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.1478e-05 - mean_absolute_error: 0.0029
# Epoch 48/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.1414e-05 - mean_absolute_error: 0.0028
# Epoch 49/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.1354e-05 - mean_absolute_error: 0.0028: 0s - loss: 1.1131e-05 - mean_abso
# Epoch 50/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.1298e-05 - mean_absolute_error: 0.0028
# Epoch 51/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.1245e-05 - mean_absolute_error: 0.0028
# Epoch 52/100
# 32850/32850 [==============================] - 1s 33us/step - loss: 1.1196e-05 - mean_absolute_error: 0.0028
# Epoch 53/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.1150e-05 - mean_absolute_error: 0.0028
# Epoch 54/100
# 32850/32850 [==============================] - 1s 40us/step - loss: 1.1106e-05 - mean_absolute_error: 0.0028
# Epoch 55/100
# 32850/32850 [==============================] - 1s 42us/step - loss: 1.1065e-05 - mean_absolute_error: 0.0028
# Epoch 56/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.1027e-05 - mean_absolute_error: 0.0027
# Epoch 57/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0990e-05 - mean_absolute_error: 0.0027
# Epoch 58/100
# 32850/32850 [==============================] - 1s 43us/step - loss: 1.0956e-05 - mean_absolute_error: 0.0027
# Epoch 59/100
# 32850/32850 [==============================] - 1s 40us/step - loss: 1.0924e-05 - mean_absolute_error: 0.0027
# Epoch 60/100
# 32850/32850 [==============================] - 1s 43us/step - loss: 1.0893e-05 - mean_absolute_error: 0.0027
# Epoch 61/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.0865e-05 - mean_absolute_error: 0.0027
# Epoch 62/100
# 32850/32850 [==============================] - 1s 37us/step - loss: 1.0837e-05 - mean_absolute_error: 0.0027
# Epoch 63/100
# 32850/32850 [==============================] - 1s 42us/step - loss: 1.0812e-05 - mean_absolute_error: 0.0027
# Epoch 64/100
# 32850/32850 [==============================] - 1s 44us/step - loss: 1.0787e-05 - mean_absolute_error: 0.0027
# Epoch 65/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0764e-05 - mean_absolute_error: 0.0027
# Epoch 66/100
# 32850/32850 [==============================] - 1s 34us/step - loss: 1.0742e-05 - mean_absolute_error: 0.0027
# Epoch 67/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0722e-05 - mean_absolute_error: 0.0027
# Epoch 68/100
# 32850/32850 [==============================] - 1s 37us/step - loss: 1.0702e-05 - mean_absolute_error: 0.0027
# Epoch 69/100
# 32850/32850 [==============================] - 1s 43us/step - loss: 1.0683e-05 - mean_absolute_error: 0.0026
# Epoch 70/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0666e-05 - mean_absolute_error: 0.0026: 0s - loss: 1.0830e-05 - mean_absolute_error: 0
# Epoch 71/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0649e-05 - mean_absolute_error: 0.0026: 0s - loss: 1.0656e-05 - mean_absolute_er
# Epoch 72/100
# 32850/32850 [==============================] - 1s 40us/step - loss: 1.0633e-05 - mean_absolute_error: 0.0026
# Epoch 73/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.0618e-05 - mean_absolute_error: 0.0026: 0s - loss: 1.0734e-05 - mean_absolute
# Epoch 74/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.0603e-05 - mean_absolute_error: 0.0026
# Epoch 75/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.0589e-05 - mean_absolute_error: 0.0026
# Epoch 76/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.0576e-05 - mean_absolute_error: 0.0026
# Epoch 77/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.0564e-05 - mean_absolute_error: 0.0026
# Epoch 78/100
# 32850/32850 [==============================] - 2s 47us/step - loss: 1.0552e-05 - mean_absolute_error: 0.0026
# Epoch 79/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0541e-05 - mean_absolute_error: 0.0026
# Epoch 80/100
# 32850/32850 [==============================] - 1s 43us/step - loss: 1.0530e-05 - mean_absolute_error: 0.0026
# Epoch 81/100
# 32850/32850 [==============================] - 1s 41us/step - loss: 1.0520e-05 - mean_absolute_error: 0.0026
# Epoch 82/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.0510e-05 - mean_absolute_error: 0.0026
# Epoch 83/100
# 32850/32850 [==============================] - 1s 44us/step - loss: 1.0500e-05 - mean_absolute_error: 0.0026
# Epoch 84/100
# 32850/32850 [==============================] - 1s 41us/step - loss: 1.0492e-05 - mean_absolute_error: 0.0026
# Epoch 85/100
# 32850/32850 [==============================] - 1s 37us/step - loss: 1.0483e-05 - mean_absolute_error: 0.0026
# Epoch 86/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.0475e-05 - mean_absolute_error: 0.0026
# Epoch 87/100
# 32850/32850 [==============================] - 1s 38us/step - loss: 1.0467e-05 - mean_absolute_error: 0.0026
# Epoch 88/100
# 32850/32850 [==============================] - 1s 41us/step - loss: 1.0460e-05 - mean_absolute_error: 0.0026
# Epoch 89/100
# 32850/32850 [==============================] - 1s 45us/step - loss: 1.0452e-05 - mean_absolute_error: 0.0026
# Epoch 90/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.0446e-05 - mean_absolute_error: 0.0026
# Epoch 91/100
# 32850/32850 [==============================] - 2s 70us/step - loss: 1.0439e-05 - mean_absolute_error: 0.0026
# Epoch 92/100
# 32850/32850 [==============================] - 2s 70us/step - loss: 1.0433e-05 - mean_absolute_error: 0.0026
# Epoch 93/100
# 32850/32850 [==============================] - 2s 75us/step - loss: 1.0427e-05 - mean_absolute_error: 0.0026
# Epoch 94/100
# 32850/32850 [==============================] - 2s 47us/step - loss: 1.0421e-05 - mean_absolute_error: 0.0025: 0s - loss: 1.0411e-05 - mean_absolute_error:
# Epoch 95/100
# 32850/32850 [==============================] - 2s 52us/step - loss: 1.0416e-05 - mean_absolute_error: 0.0025: 1s - loss: 1.0408e-05 - mean
# Epoch 96/100
# 32850/32850 [==============================] - 2s 48us/step - loss: 1.0411e-05 - mean_absolute_error: 0.0025
# Epoch 97/100
# 32850/32850 [==============================] - 1s 41us/step - loss: 1.0406e-05 - mean_absolute_error: 0.0025
# Epoch 98/100
# 32850/32850 [==============================] - 1s 39us/step - loss: 1.0401e-05 - mean_absolute_error: 0.0025
# Epoch 99/100
# 32850/32850 [==============================] - 1s 36us/step - loss: 1.0396e-05 - mean_absolute_error: 0.0025
# Epoch 100/100
# 32850/32850 [==============================] - 1s 35us/step - loss: 1.0392e-05 - mean_absolute_error: 0.0025: 0s - loss: 1.0359e-05 - mean_absolute_error:
# 10950/10950 [==============================] - 0s 20us/step
# [1.0487231903118392e-05, 0.0025252502474861567]

# %%
# To see the model's plotting: tensorboard --logdir ./Graph
